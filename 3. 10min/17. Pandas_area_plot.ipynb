# %% [markdown]
# ## area plot 산점도

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용 시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  0.242272  0.111890  0.093616  0.056518
# 1  0.600308  0.361611  0.018139  0.798664
# 2  0.076925  0.962834  0.781236  0.707607
# 3  0.146772  0.107610  0.404829  0.608433
# 4  0.882149  0.897358  0.512310  0.824072

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(grid = True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(grid = True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked = False, grid = True)
# area plot은 stacked = True가 default임
# Out:
# <AxesSubplot:>
